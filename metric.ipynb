# %%
import pandas as pd

# %%
acc=pd.read_csv('aac_metrics.tsv',sep='\t')

# %%
acc.style.highlight_max(color = 'red', axis = 0)
# Out:
# <style type="text/css">
# #T_de835_row3_col5, #T_de835_row5_col2, #T_de835_row5_col3, #T_de835_row6_col0, #T_de835_row6_col1, #T_de835_row7_col7, #T_de835_row9_col4, #T_de835_row10_col6 {
#   background-color: red;
# }
# </style>
# <table id="T_de835">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de835_level0_col0" class="col_heading level0 col0" >   bleu_1</th>
#       <th id="T_de835_level0_col1" class="col_heading level0 col1" >   bleu_2</th>
#       <th id="T_de835_level0_col2" class="col_heading level0 col2" >   bleu_3</th>
#       <th id="T_de835_level0_col3" class="col_heading level0 col3" >    bleu_4</th>
#       <th id="T_de835_level0_col4" class="col_heading level0 col4" >   meteor</th>
#       <th id="T_de835_level0_col5" class="col_heading level0 col5" >  rouge_l</th>
#       <th id="T_de835_level0_col6" class="col_heading level0 col6" >  cider_d</th>
# ...

# %%
metrics=pd.read_csv('metrics.tsv',sep='\t')

# %%
metrics.style.highlight_max(color = 'green', axis = 0)
# Out:
# <style type="text/css">
# #T_cd47b_row3_col0, #T_cd47b_row3_col7, #T_cd47b_row7_col9, #T_cd47b_row9_col5, #T_cd47b_row9_col6, #T_cd47b_row10_col1, #T_cd47b_row10_col2, #T_cd47b_row10_col3, #T_cd47b_row10_col4, #T_cd47b_row10_col8 {
#   background-color: green;
# }
# </style>
# <table id="T_cd47b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd47b_level0_col0" class="col_heading level0 col0" >   bleu_1</th>
#       <th id="T_cd47b_level0_col1" class="col_heading level0 col1" >    bleu_2</th>
#       <th id="T_cd47b_level0_col2" class="col_heading level0 col2" >    bleu_3</th>
#       <th id="T_cd47b_level0_col3" class="col_heading level0 col3" >    bleu_4</th>
#       <th id="T_cd47b_level0_col4" class="col_heading level0 col4" >  rouge_l</th>
#       <th id="T_cd47b_level0_col5" class="col_heading level0 col5" >   dist_1</th>
#       <th id="T_cd47b_level0_col6" class="col_heading level0 col6" >  dist_2</th>
# ...
